# %% [markdown]
# <a href="https://colab.research.google.com/github/nsmsm/ASL/blob/master/%EA%B3%BC%EC%A0%9C_2%EC%B0%A8_%EB%AC%B8%EC%8A%B9%EB%AA%85_(201985010061)_10_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fashion MNIST (or CIFAR10)를 분류하는 CNN 학습하기.

# %%
import tensorflow as tf
from tensorflow.keras import datasets, models
from tensorflow.keras.layers import Flatten, Dense, Dropout, Conv2D, MaxPool2D
from tensorflow.keras.utils import plot_model

print(tf.__version__)
# Out:
# 2.3.0

# %%
fashion_mnist = datasets.fashion_mnist
(train_x, train_y), (test_x, test_y) = fashion_mnist.load_data()

## train_x : need for learning DNN
## ext_train_x : need for learning CNN
train_x = train_x/255.0
test_x = test_x/255.0

ext_train_x = train_x.reshape((60000, 28, 28, 1))
ext_test_x = test_x.reshape((10000, 28, 28, 1))

## show the dimensions of train_x and ext_train_x
print(train_x.shape)
print(ext_train_x.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000, 28, 28, 1)

# %%
## Define a DNN model and a CNN model
## set the number of params. of DNN and the number of params. of CNN to be similar

## DNN model
dnn_model = models.Sequential([
  Flatten(input_shape=(28,28)),
  Dense(110, activation='relu'),
  Dense(100, activation='relu'),
  Dense(10, activation='softmax')]
)

## CNN model
cnn_model = models.Sequential([
  Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
  MaxPool2D(pool_size=(2, 2), strides=(2,2), padding='valid'),
  Conv2D(64, (3, 3), activation='relu'),
  MaxPool2D(pool_size=(2, 2), strides=(2,2), padding='valid'),
  Conv2D(64, (3, 3), activation='relu'),
  Flatten(),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax')
])

dnn_model.summary()
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense (Dense)                (None, 110)               86350
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               11100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 98,460
# Trainable params: 98,460
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                36928
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %%
dnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
cnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

dnn_hist=dnn_model.fit(train_x, train_y, epochs=20, batch_size=100, validation_split=0.10)
cnn_hist=cnn_model.fit(ext_train_x, train_y, epochs=20, batch_size=100, validation_split=0.10)
# Out:
# Epoch 1/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.5436 - accuracy: 0.8105 - val_loss: 0.4432 - val_accuracy: 0.8458
# Epoch 2/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.3882 - accuracy: 0.8607 - val_loss: 0.3687 - val_accuracy: 0.8630
# Epoch 3/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.3464 - accuracy: 0.8734 - val_loss: 0.3628 - val_accuracy: 0.8652
# Epoch 4/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.3213 - accuracy: 0.8829 - val_loss: 0.3513 - val_accuracy: 0.8705
# Epoch 5/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.3027 - accuracy: 0.8881 - val_loss: 0.3392 - val_accuracy: 0.8795
# Epoch 6/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2895 - accuracy: 0.8928 - val_loss: 0.3195 - val_accuracy: 0.8853
# Epoch 7/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2756 - accuracy: 0.8969 - val_loss: 0.3286 - val_accuracy: 0.8833
# Epoch 8/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2627 - accuracy: 0.9031 - val_loss: 0.3280 - val_accuracy: 0.8857
# Epoch 9/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2520 - accuracy: 0.9066 - val_loss: 0.3340 - val_accuracy: 0.8783
# Epoch 10/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2432 - accuracy: 0.9094 - val_loss: 0.3432 - val_accuracy: 0.8790
# Epoch 11/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2369 - accuracy: 0.9123 - val_loss: 0.3142 - val_accuracy: 0.8880
# Epoch 12/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2260 - accuracy: 0.9159 - val_loss: 0.3147 - val_accuracy: 0.8885
# Epoch 13/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2217 - accuracy: 0.9179 - val_loss: 0.3470 - val_accuracy: 0.8805
# Epoch 14/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2127 - accuracy: 0.9211 - val_loss: 0.3216 - val_accuracy: 0.8887
# Epoch 15/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2096 - accuracy: 0.9213 - val_loss: 0.3362 - val_accuracy: 0.8878
# Epoch 16/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.2009 - accuracy: 0.9247 - val_loss: 0.3415 - val_accuracy: 0.8882
# Epoch 17/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1944 - accuracy: 0.9267 - val_loss: 0.3392 - val_accuracy: 0.8910
# Epoch 18/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1868 - accuracy: 0.9295 - val_loss: 0.3424 - val_accuracy: 0.8907
# Epoch 19/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1819 - accuracy: 0.9316 - val_loss: 0.3383 - val_accuracy: 0.8937
# Epoch 20/20
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1809 - accuracy: 0.9315 - val_loss: 0.3538 - val_accuracy: 0.8897
# Epoch 1/20
# 540/540 [==============================] - 2s 4ms/step - loss: 0.5991 - accuracy: 0.7795 - val_loss: 0.4068 - val_accuracy: 0.8465
# Epoch 2/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.3685 - accuracy: 0.8664 - val_loss: 0.3315 - val_accuracy: 0.8797
# Epoch 3/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.3153 - accuracy: 0.8859 - val_loss: 0.2998 - val_accuracy: 0.8878
# Epoch 4/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.2831 - accuracy: 0.8968 - val_loss: 0.3276 - val_accuracy: 0.8743
# Epoch 5/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.2612 - accuracy: 0.9047 - val_loss: 0.2752 - val_accuracy: 0.8975
# Epoch 6/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.2413 - accuracy: 0.9116 - val_loss: 0.2525 - val_accuracy: 0.9087
# Epoch 7/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.2252 - accuracy: 0.9172 - val_loss: 0.2643 - val_accuracy: 0.9017
# Epoch 8/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.2105 - accuracy: 0.9226 - val_loss: 0.2691 - val_accuracy: 0.9032
# Epoch 9/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1947 - accuracy: 0.9288 - val_loss: 0.2462 - val_accuracy: 0.9118
# Epoch 10/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1827 - accuracy: 0.9321 - val_loss: 0.2422 - val_accuracy: 0.9130
# Epoch 11/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1675 - accuracy: 0.9371 - val_loss: 0.2470 - val_accuracy: 0.9150
# Epoch 12/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1580 - accuracy: 0.9422 - val_loss: 0.2612 - val_accuracy: 0.9123
# Epoch 13/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1456 - accuracy: 0.9458 - val_loss: 0.2558 - val_accuracy: 0.9113
# Epoch 14/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1346 - accuracy: 0.9498 - val_loss: 0.2712 - val_accuracy: 0.9090
# Epoch 15/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1249 - accuracy: 0.9537 - val_loss: 0.2644 - val_accuracy: 0.9112
# Epoch 16/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1158 - accuracy: 0.9571 - val_loss: 0.2844 - val_accuracy: 0.9157
# Epoch 17/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1056 - accuracy: 0.9609 - val_loss: 0.3046 - val_accuracy: 0.9128
# Epoch 18/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0956 - accuracy: 0.9648 - val_loss: 0.2922 - val_accuracy: 0.9175
# Epoch 19/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0907 - accuracy: 0.9664 - val_loss: 0.3136 - val_accuracy: 0.9142
# Epoch 20/20
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0814 - accuracy: 0.9695 - val_loss: 0.3378 - val_accuracy: 0.9085

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7,5))
plt.plot(dnn_hist.history['accuracy'], 'r--', label='train (DNN)')
plt.plot(dnn_hist.history['val_accuracy'], 'r-', label='valid (DNN)')
plt.plot(cnn_hist.history['accuracy'], 'b--', label='train (CNN)')
plt.plot(cnn_hist.history['val_accuracy'], 'b-', label='valid (CNN)')
plt.ylim([0.8,1.005])
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(loc='upper left', fontsize=12)
plt.title('Accuracy trace plot', fontsize=15)
plt.show()

dnn_sc = dnn_model.evaluate(test_x, test_y)
cnn_sc = cnn_model.evaluate(ext_test_x, test_y)
print('Performance of DNN')
print('...test accuracy: %.3f, test loss: %.3f'%(dnn_sc[1], dnn_sc[0]))
print('Performance of CNN')
print('...test accuracy: %.3f, test loss: %.3f'%(cnn_sc[1], cnn_sc[0]))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3682 - accuracy: 0.8837
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3551 - accuracy: 0.9042
# Performance of DNN
# ...test accuracy: 0.884, test loss: 0.368
# Performance of CNN
# ...test accuracy: 0.904, test loss: 0.355

# %% [markdown]
# 전이학습 활용해보기.

# %%
import keras
from keras.datasets import cifar10
from tensorflow.keras import models
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
from keras.applications.inception_v3 import InceptionV3, preprocess_input

import numpy as np

# %%
## load cifar data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(y_train.shape)
y_train = np.squeeze(y_train)
print(y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# (50000, 1)
# (50000,)

# %%
import tensorflow as tf
import gc
import matplotlib.pyplot as plt

## resize the cifar data
## from 32*32*3 to 75*75*3
train_images = tf.constant(x_train, dtype=tf.float32)
big_train_x = tf.image.resize(train_images, [75,75]).numpy()
print(big_train_x.shape)

## plot images
plt.figure(figsize=(5,5))
for col1 in range(9):
  plt.subplot(3,3,col1+1)
  plt.imshow(train_images[col1]/255.)
  plt.xticks([])
  plt.yticks([])
plt.show()

del x_train, train_images  ## delete the redundant variables
gc.collect()               ## free memory

test_images = tf.constant(x_test, dtype=tf.float32)
big_test_x = tf.image.resize(test_images, [75,75]).numpy()
print(big_test_x.shape)
del x_test, test_images
gc.collect()
# Out:
# (50000, 75, 75, 3)
# (10000, 75, 75, 3)
# 0

# %%
## pre-process train and test data
big_train_x = preprocess_input(big_train_x)
big_test_x = preprocess_input(big_test_x)
print(big_train_x.shape)
print(big_train_x[0])
# Out:
# (50000, 75, 75, 3)
# [[[-0.5372549  -0.5137255  -0.5058824 ]
#   [-0.5548235  -0.5312941  -0.52564704]
#   [-0.608366   -0.5848366  -0.58588237]
#   ...
#   [ 0.17856205 -0.02300656 -0.19660127]
#   [ 0.16517651 -0.02635294 -0.19325489]
#   [ 0.16078436 -0.02745098 -0.19215685]]
#
#  [[-0.5844706  -0.5598432  -0.5530981 ]
#   [-0.6020392  -0.57802665 -0.5731702 ]
#   [-0.6555817  -0.6334431  -0.6343425 ]
#   ...
#   [ 0.14565754 -0.0667451  -0.25084442]
#   [ 0.13555133 -0.06774902 -0.24468708]
#   [ 0.13223529 -0.06807846 -0.24266666]]
#
#  [[-0.728366   -0.7003922  -0.69699347]
#   [-0.74593467 -0.7204497  -0.7180026 ]
#   [-0.7994771  -0.78157735 -0.7820305 ]
#   ...
#   [ 0.0453769  -0.20004356 -0.41615683]
#   [ 0.04526532 -0.19390851 -0.40143263]
#   [ 0.04522872 -0.19189543 -0.39660132]]
#
#  ...
#
#  [[ 0.40156865  0.10718954 -0.17908484]
#   [ 0.39293075  0.09009671 -0.22315276]
#   [ 0.36660564  0.0380044  -0.35745507]
#   ...
#   [-0.12388647 -0.37902373 -0.5810716 ]
#   [-0.19103765 -0.4337932  -0.59847295]
#   [-0.21307158 -0.4517644  -0.6041827 ]]
#
#  [[ 0.39152944  0.12392163 -0.11215675]
#   [ 0.38195455  0.1072973  -0.14123285]
#   [ 0.3527738   0.05663276 -0.22984558]
#   ...
#   [ 0.03651774 -0.21627706 -0.43115282]
#   [-0.0506227  -0.29531914 -0.4656877 ]
#   [-0.07921547 -0.32125473 -0.47701943]]
#
#  [[ 0.38823533  0.12941182 -0.09019607]
#   [ 0.378353    0.11294115 -0.11435294]
#   [ 0.34823525  0.06274509 -0.18797386]
#   ...
#   [ 0.08915007 -0.16287601 -0.38196087]
#   [-0.00454915 -0.24988246 -0.4221177 ]
#   [-0.03529412 -0.27843136 -0.4352941 ]]]

# %%
## load inceptionV3 model
model = InceptionV3(weights='imagenet', include_top=False, input_shape=(75, 75, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 3s 0us/step

# %%
## extract the penultimate features
## train data
train_features = model.predict(big_train_x)
print(train_features.shape)
train_features = np.squeeze(train_features)
print(train_features.shape)

## test data
test_features = model.predict(big_test_x)
print(test_features.shape)
test_features = np.squeeze(test_features)
print(test_features.shape)

del model, big_train_x, big_test_x
gc.collect()
# Out:
# (50000, 1, 1, 2048)
# (50000, 2048)
# (10000, 1, 1, 2048)
# (10000, 2048)
# 14709

# %%
multi_logistic_model = models.Sequential([
  Dense(10, activation='softmax', input_shape=(2048,))]
)
multi_logistic_model.summary()

plot_model(multi_logistic_model, show_shapes=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 20,490
# Trainable params: 20,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
multi_logistic_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

hist=multi_logistic_model.fit(train_features, y_train, epochs=20, batch_size=100, validation_split=0.10)
# Out:
# Epoch 1/20
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3112 - accuracy: 0.5542 - val_loss: 1.1072 - val_accuracy: 0.6222
# Epoch 2/20
# 450/450 [==============================] - 1s 2ms/step - loss: 1.0343 - accuracy: 0.6463 - val_loss: 1.0671 - val_accuracy: 0.6398
# Epoch 3/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.9772 - accuracy: 0.6668 - val_loss: 1.0615 - val_accuracy: 0.6408
# Epoch 4/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.9445 - accuracy: 0.6768 - val_loss: 1.0815 - val_accuracy: 0.6388
# Epoch 5/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.9207 - accuracy: 0.6851 - val_loss: 1.0618 - val_accuracy: 0.6426
# Epoch 6/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.9078 - accuracy: 0.6881 - val_loss: 1.0616 - val_accuracy: 0.6356
# Epoch 7/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8945 - accuracy: 0.6916 - val_loss: 1.0662 - val_accuracy: 0.6356
# Epoch 8/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8809 - accuracy: 0.6959 - val_loss: 1.0772 - val_accuracy: 0.6352
# Epoch 9/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8737 - accuracy: 0.6964 - val_loss: 1.1142 - val_accuracy: 0.6302
# Epoch 10/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8642 - accuracy: 0.7001 - val_loss: 1.0902 - val_accuracy: 0.6376
# Epoch 11/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8615 - accuracy: 0.7027 - val_loss: 1.1178 - val_accuracy: 0.6282
# Epoch 12/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8515 - accuracy: 0.7057 - val_loss: 1.1111 - val_accuracy: 0.6258
# Epoch 13/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8473 - accuracy: 0.7069 - val_loss: 1.0923 - val_accuracy: 0.6336
# Epoch 14/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8400 - accuracy: 0.7088 - val_loss: 1.1069 - val_accuracy: 0.6288
# Epoch 15/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8360 - accuracy: 0.7092 - val_loss: 1.1126 - val_accuracy: 0.6362
# Epoch 16/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8314 - accuracy: 0.7127 - val_loss: 1.1021 - val_accuracy: 0.6366
# Epoch 17/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8280 - accuracy: 0.7140 - val_loss: 1.1235 - val_accuracy: 0.6352
# Epoch 18/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8211 - accuracy: 0.7153 - val_loss: 1.1103 - val_accuracy: 0.6350
# Epoch 19/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8192 - accuracy: 0.7160 - val_loss: 1.1283 - val_accuracy: 0.6354
# Epoch 20/20
# 450/450 [==============================] - 1s 2ms/step - loss: 0.8165 - accuracy: 0.7165 - val_loss: 1.1156 - val_accuracy: 0.6334

# %%
plt.plot(hist.history['accuracy'], 'b--', label='train')
plt.plot(hist.history['val_accuracy'], 'r-', label='valid')
plt.ylim([0.5,0.75])
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Accuracy', fontsize=12)
plt.legend(loc='lower right', fontsize=12)
plt.title('Accuracy trace plot', fontsize=15)
plt.show()

sc = multi_logistic_model.evaluate(test_features, y_test)
print('...accuracy: %.3f, loss: %.3f'%(sc[1], sc[0]))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.1091 - accuracy: 0.6406
# ...accuracy: 0.641, loss: 1.109
